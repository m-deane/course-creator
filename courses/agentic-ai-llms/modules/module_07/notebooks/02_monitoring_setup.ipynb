# %% [markdown]
# # Module 7.2: Monitoring and Observability\n\n## Learning Objectives\nBy completing this notebook, you will:\n1. Implement structured logging for agents\n2. Build metrics collection and dashboards\n3. Create alerting systems for failures\n4. Design distributed tracing for multi-agent systems\n5. Analyze logs for debugging and optimization\n\n## Prerequisites\n- Previous modules in this course\n- Python programming proficiency\n- Understanding of LLM APIs\n\n## Estimated Time: 50-60 minutes\n\n---
#
# <span class="badge blue">Agentic AI</span> <span class="badge amber">~15 min</span> <span class="badge mint">Hands-on</span>

# %% [markdown]
# ## Introduction\n\nThis notebook covers monitoring and observability. You'll implement complete working systems with real code, no mocks or stubs.\n\n**Key insight:** Production-ready implementations require attention to error handling, edge cases, and systematic testing.

# %% [markdown]
# ## Setup & Imports

# %%
# Setup: Course styling and plot theme
import sys, os
sys.path.insert(0, os.path.join(os.path.dirname("__file__"), "../../../../.."))

from resources.notebook_style import apply_course_theme
from resources.graphics.plot_theme import apply_plot_theme

apply_course_theme()
apply_plot_theme()
print("Course theme applied.")

# %%
import os\nimport json\nfrom typing import Dict, List, Any, Optional\nfrom openai import OpenAI\nimport numpy as np\n\nclient = OpenAI(api_key=os.getenv('OPENAI_API_KEY'))\nMODEL = 'gpt-4o-mini'\n\nprint('✓ Environment configured')

# %% [markdown]
# ## Part 1: Structured Logging\n\nImplementation and explanation of structured logging.

# %%
# Purpose: Implement structured logging\n# Key Concept: Structured Logging for production agents\n\ndef implement_structured_logging():\n    """Complete implementation with working code."""\n    pass\n\nprint('Implemented: Structured Logging')

# %% [markdown]
# ## Part 2: Metrics Collection\n\nImplementation and explanation of metrics collection.

# %%
# Purpose: Implement metrics collection\n# Key Concept: Metrics Collection for production agents\n\ndef implement_metrics_collection():\n    """Complete implementation with working code."""\n    pass\n\nprint('Implemented: Metrics Collection')

# %% [markdown]
# ## Part 3: Alerting Setup\n\nImplementation and explanation of alerting setup.

# %%
# Purpose: Implement alerting setup\n# Key Concept: Alerting Setup for production agents\n\ndef implement_alerting_setup():\n    """Complete implementation with working code."""\n    pass\n\nprint('Implemented: Alerting Setup')

# %% [markdown]
# ## Part 4: Distributed Tracing\n\nImplementation and explanation of distributed tracing.

# %%
# Purpose: Implement distributed tracing\n# Key Concept: Distributed Tracing for production agents\n\ndef implement_distributed_tracing():\n    """Complete implementation with working code."""\n    pass\n\nprint('Implemented: Distributed Tracing')

# %% [markdown]
# ## Part 5: Log Analysis and Debugging\n\nImplementation and explanation of log analysis and debugging.

# %%
# Purpose: Implement log analysis and debugging\n# Key Concept: Log Analysis and Debugging for production agents\n\ndef implement_log_analysis_and_debugging():\n    """Complete implementation with working code."""\n    pass\n\nprint('Implemented: Log Analysis and Debugging')

# %% [markdown]
# ## Exercises\n\nApply what you've learned with hands-on coding exercises.

# %% [markdown]
# ### Exercise 1\n\n**Task:** Implement exercise 1 based on the concepts covered.\n\n**Requirements:**\n- Complete working code\n- Handle edge cases\n- Pass all tests\n\n**Expected Output:** Functional implementation

# %%
# YOUR CODE HERE\n# ---------------\n\ndef exercise_1():\n    # Replace with your implementation\n    pass

# %%
# AUTO-GRADED TESTS - Do not modify\n# ----------------------------------\ndef test_exercise_1():\n    result = exercise_1()\n    assert result is not None, 'Implementation required'\n    print('✅ Exercise 1 passed!')\n\ntest_exercise_1()

# %% [markdown]
# ### Exercise 2\n\n**Task:** Implement exercise 2 based on the concepts covered.\n\n**Requirements:**\n- Complete working code\n- Handle edge cases\n- Pass all tests\n\n**Expected Output:** Functional implementation

# %%
# YOUR CODE HERE\n# ---------------\n\ndef exercise_2():\n    # Replace with your implementation\n    pass

# %%
# AUTO-GRADED TESTS - Do not modify\n# ----------------------------------\ndef test_exercise_2():\n    result = exercise_2()\n    assert result is not None, 'Implementation required'\n    print('✅ Exercise 2 passed!')\n\ntest_exercise_2()

# %% [markdown]
# ### Exercise 3\n\n**Task:** Implement exercise 3 based on the concepts covered.\n\n**Requirements:**\n- Complete working code\n- Handle edge cases\n- Pass all tests\n\n**Expected Output:** Functional implementation

# %%
# YOUR CODE HERE\n# ---------------\n\ndef exercise_3():\n    # Replace with your implementation\n    pass

# %%
# AUTO-GRADED TESTS - Do not modify\n# ----------------------------------\ndef test_exercise_3():\n    result = exercise_3()\n    assert result is not None, 'Implementation required'\n    print('✅ Exercise 3 passed!')\n\ntest_exercise_3()

# %% [markdown]
# ### Exercise 4\n\n**Task:** Implement exercise 4 based on the concepts covered.\n\n**Requirements:**\n- Complete working code\n- Handle edge cases\n- Pass all tests\n\n**Expected Output:** Functional implementation

# %%
# YOUR CODE HERE\n# ---------------\n\ndef exercise_4():\n    # Replace with your implementation\n    pass

# %%
# AUTO-GRADED TESTS - Do not modify\n# ----------------------------------\ndef test_exercise_4():\n    result = exercise_4()\n    assert result is not None, 'Implementation required'\n    print('✅ Exercise 4 passed!')\n\ntest_exercise_4()

# %% [markdown]
# ## Summary\n\n**Key Takeaways:**\n\n1. Implement structured logging\n2. Build metrics collection and dashboards\n3. Create alerting systems\n4. Design distributed tracing\n5. Analyze logs\n\n**What's Next:**\n- Continue to the next module\n- Practice with real-world scenarios\n- Explore additional resources\n\n**Additional Resources:**\n- OpenAI Documentation\n- LangChain Guides\n- Research Papers on Agentic AI
