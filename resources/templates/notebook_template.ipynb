# %% [markdown]
# # Notebook Title
#
# > **Module N** | Course Name | ~15 min
#
# ---
#
# ## Learning Objectives
#
# - Objective 1: What you will understand after this notebook
# - Objective 2: What you will be able to implement
# - Objective 3: The practical skill you will gain

# %%
# === Setup ===
import sys
import os

# Add project root to path for imports
sys.path.insert(0, os.path.join(os.path.dirname("__file__"), "../../../"))

# Apply course styling
from resources.notebook_style import apply_course_theme
from resources.graphics.plot_theme import apply_plot_theme

apply_course_theme()
apply_plot_theme()

# Standard imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ---
#
# ## Section 1: Getting Started
#
# Brief context for this section. Explain what we are about to do and why.

# %%
# Your code here
# Load data, perform initial exploration, or set up the problem

# %% [markdown]
# ---
#
# ## Summary
#
# **Key Takeaways:**
#
# 1. Takeaway 1 — what was the main concept
# 2. Takeaway 2 — what was the practical skill
# 3. Takeaway 3 — what to explore next
#
# **Next Steps:**
#
# - Companion guide: `guides/XX_concept_guide.md`
# - Slide deck: `guides/XX_concept_slides.md`
# - Exercises: `exercises/XX_concept_exercises.py`
